# %% [markdown]
# # run3 : ref no fold (3 classes) on small unet
#
# * img reduce from  3x352x352 to 3x88x88
# * no folding
# * 3 classes
# * model = UNetSMALL

# %%
import sys,os
#apped depend on which machine 
paths = ['/data/solai/aiArmory/pytorch/', '/home/vlad/max78/aiArmory/pytorch/']
for path in paths:
    if os.path.exists(path):
        sys.path.append(path)
from armoInclude import *
from armoTrain import basicModel
# Out:
# 2024-08-11 22:05:27.895531: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## conf

# %%
# myPC
DATASET_PATH = '/data/tinyai/maxCNN/ai8x-training/data/CamVid'
MODEL_PATH = './unet_model_small_x88_c3_e50_F1.pt'  
EPOCHS_TO_RUN = 50
REDO = False

# ## runServer
# DATASET_PATH = '/home/vlad/Data/CamVid'
# MODEL_PATH = '/tmp/unet_model_small_x88_c3_e50_F1.pt'  
# REDO = True
# EPOCHS_TO_RUN = 50

# %%
IMAGE_SIZE = (88, 88)  
BATCH_SIZE = 8

## Model - basic reference model with no fold
NUM_CLASS   =   4   ## class+1 for none
NUM_CHANN   =   3
FOLD_RATIO  =   1

# %%
runDevice = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') #<! The 1st CUDA device
print(f'runDevice: {runDevice}')
# Out:
# runDevice: cuda:0

# %% [markdown]
# ## Layers

# %%
class UNetSmall(nn.Module):
    """
    Small size UNet model for x86 architecture using PyTorch
    """
    def __init__(self, num_classes=4, num_channels=3, bias=True):

        super().__init__()

        self.enc1 = nn.Sequential(
            nn.Conv2d(num_channels, 4, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(4),
            nn.ReLU(inplace=True)
        )

        self.enc2 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(4, 8, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace=True)
        )

        self.enc3 = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(8, 32, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)
        )

        self.bneck = nn.Sequential(
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )

        self.upconv3 = nn.ConvTranspose2d(64, 32, 3, stride=2, padding=1, output_padding=1)

        self.dec3 = nn.Sequential(
            nn.Conv2d(64, 32, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)
        )

        self.upconv2 = nn.ConvTranspose2d(32, 8, 3, stride=2, padding=1, output_padding=1)

        self.dec2 = nn.Sequential(
            nn.Conv2d(16, 8, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(8),
            nn.ReLU(inplace=True)
        )

        self.upconv1 = nn.ConvTranspose2d(8, 4, 3, stride=2, padding=1, output_padding=1)

        self.dec1 = nn.Sequential(
            nn.Conv2d(8, 16, 3, stride=1, padding=1, bias=bias),
            nn.BatchNorm2d(16),
            nn.ReLU(inplace=True)
        )

        self.conv = nn.Conv2d(16, num_classes, 1, stride=1, padding=0, bias=bias)

    def forward(self, x):
        """Forward prop"""
        enc1 = self.enc1(x)
        enc2 = self.enc2(enc1)
        enc3 = self.enc3(enc2)

        bottleneck = self.bneck(enc3)

        dec3 = self.upconv3(bottleneck)
        dec3 = torch.cat((dec3, enc3), dim=1)
        dec3 = self.dec3(dec3)
        dec2 = self.upconv2(dec3)
        dec2 = torch.cat((dec2, enc2), dim=1)
        dec2 = self.dec2(dec2)
        dec1 = self.upconv1(dec2)
        dec1 = torch.cat((dec1, enc1), dim=1)
        dec1 = self.dec1(dec1)
        return self.conv(dec1)

# %% [markdown]
# ## data

# %%
filter_label = [0,5,21,17] # car sky road

# %%
class CamVidDataset(Dataset):
    def __init__(self, image_dir, label_dir, image_transform=None, label_transform=None):
        self.image_dir = image_dir
        self.label_dir = label_dir
        self.image_transform = image_transform
        self.label_transform = label_transform
        self.image_paths = sorted([os.path.join(image_dir, f) for f in os.listdir(image_dir)])
        self.label_paths = sorted([os.path.join(label_dir, f) for f in os.listdir(label_dir)])
        
        # Load class dictionary
        class_dict_path = os.path.join(DATASET_PATH, 'class_dict.csv')
        class_dict = pd.read_csv(class_dict_path)
        self.colormap = np.zeros((256**3,), dtype=int)

        if filter_label:
            print(f"...will filter classes")
            class_dict_filter = class_dict.filter(filter_label, axis=0)
        else:
            class_dict_filter = class_dict
        
        for i, row in class_dict_filter.iterrows():
            r, g, b = row['r'], row['g'], row['b']
            self.colormap[r * 256**2 + g * 256 + b] = i

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert('RGB')
        label = Image.open(self.label_paths[idx]).convert('RGB')

        if self.image_transform:
            image = self.image_transform(image)
        if self.label_transform:
            label = self.label_transform(label)
        
        label = self.encode_segmap(np.array(label))  # Convert label to numpy array before encoding

        if filter_label:
            mapping = {old_value: new_index for new_index, old_value in enumerate(filter_label)}
            ## nromilize label by mapping
            label = np.vectorize(mapping.get)(label)

        return image, torch.from_numpy(label).long()

    def encode_segmap(self, mask):
        mask = mask.astype(int)
        index = mask[:, :, 0] * 256**2 + mask[:, :, 1] * 256 + mask[:, :, 2]
        return self.colormap[index]

# Step 4: Data Transformation and DataLoader
image_transform = TorchVisionTrns.Compose([
    TorchVisionTrns.Resize(IMAGE_SIZE),
    TorchVisionTrns.ToTensor()
])

label_transform = TorchVisionTrns.Compose([
    TorchVisionTrns.Resize(IMAGE_SIZE)
])

train_dataset = CamVidDataset(
    image_dir=os.path.join(DATASET_PATH, 'train'),
    label_dir=os.path.join(DATASET_PATH, 'train_labels'),
    image_transform=image_transform,
    label_transform=label_transform
)

val_dataset = CamVidDataset(
    ## change to have more data in val then in test
    image_dir=os.path.join(DATASET_PATH, 'test'),
    label_dir=os.path.join(DATASET_PATH, 'test_labels'),
    image_transform=image_transform,
    label_transform=label_transform
)

test_dataset = CamVidDataset(
    ## change to have more data in val then in test
    image_dir=os.path.join(DATASET_PATH, 'val'),
    label_dir=os.path.join(DATASET_PATH, 'val_labels'),
    image_transform=image_transform,
    label_transform=label_transform
)

dlTrain = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
dlVal = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
dlTest = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# ...will filter classes
# ...will filter classes
# ...will filter classes
# /home/vlad/miniconda3/envs/WorkshopCUDAEnv/lib/python3.11/site-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
print(f"train_loader len =  {len(dlTrain.dataset)}")
print(f"val_loader len =  {len(dlVal.dataset)}")
print(f"test_loader len =  {len(dlTest.dataset)}")
# Out:
# train_loader len =  369
# val_loader len =  232
# test_loader len =  100

# %% [markdown]
# # model

# %%
oModel = UNetSmall(num_classes=NUM_CLASS, num_channels=NUM_CHANN, bias=True)
oModel = oModel.to(runDevice)
myTrain = basicModel(model=oModel,CheckpointFile=MODEL_PATH)

# %% [markdown]
# ### loss

# %%
hL = nn.CrossEntropyLoss()
hL = hL.to(runDevice)

# %% [markdown]
# ### score

# %%
# Given the shape of outputs is [8, 32, 80, 80], 
# applying torch.max(outputs, 1) will reduce the dimension
# from 32 to 1 by finding the maximum value along the
# second dimension (dim=1). 
# vals:  will be The maximum values along the specified dimension (dim=1) 
# preds: The indices of the maximum values along the specified dimension
#         with shape of preds will be [8, 80, 80].

def hS(outputs, labels):
    vals , preds = torch.max(outputs, 1)
    corrects = torch.sum(preds.data == labels.data)
    return corrects.double() / labels.numel()

# %% [markdown]
# ### optimizer

# %%
oOpt = torch.optim.AdamW(oModel.parameters(), lr = 1e-4, betas = (0.9, 0.99), weight_decay = 1e-5)

# %% [markdown]
# ### scheduler

# %%
oSch = torch.optim.lr_scheduler.OneCycleLR(oOpt, max_lr = 5e-4, total_steps = EPOCHS_TO_RUN)

# %% [markdown]
# ### summary

# %%
myTrain.verify( dlTrain, dlVal, oOpt, EPOCHS_TO_RUN , BATCH_SIZE , hL, hS, oSch = oSch)
# Out:
# =======================  info   =========================================================
# numEpoch = 50 ; batchSize = 8
# Train:
#     len train dataset 369 / batchSize  8 = len Train 47
#     dlTrain: iter tX shape   = torch.Size([8, 3, 88, 88])
#     dlTrain: iter vY ; shape = torch.Size([8, 88, 88])
# Val:
#     dlVal  : tensor[0].shape = torch.Size([8, 3, 88, 88])
#     dlVal  : tensor[1].shape = torch.Size([8, 88, 88])
# =======================  summary   =========================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# UNetSmall                                [8, 4, 88, 88]            --
# ├─Sequential: 1-1                        [8, 4, 88, 88]            --
# │    └─Conv2d: 2-1                       [8, 4, 88, 88]            112
# │    └─BatchNorm2d: 2-2                  [8, 4, 88, 88]            8
# │    └─ReLU: 2-3                         [8, 4, 88, 88]            --
# ├─Sequential: 1-2                        [8, 8, 44, 44]            --
# │    └─MaxPool2d: 2-4                    [8, 4, 44, 44]            --
# │    └─Conv2d: 2-5                       [8, 8, 44, 44]            296
# │    └─BatchNorm2d: 2-6                  [8, 8, 44, 44]            16
# │    └─ReLU: 2-7                         [8, 8, 44, 44]            --
# ├─Sequential: 1-3                        [8, 32, 22, 22]           --
# │    └─MaxPool2d: 2-8                    [8, 8, 22, 22]            --
# │    └─Conv2d: 2-9                       [8, 32, 22, 22]           2,336
# │    └─BatchNorm2d: 2-10                 [8, 32, 22, 22]           64
# │    └─ReLU: 2-11                        [8, 32, 22, 22]           --
# ├─Sequential: 1-4                        [8, 64, 11, 11]           --
# │    └─MaxPool2d: 2-12                   [8, 32, 11, 11]           --
# │    └─Conv2d: 2-13                      [8, 64, 11, 11]           18,496
# │    └─BatchNorm2d: 2-14                 [8, 64, 11, 11]           128
# │    └─ReLU: 2-15                        [8, 64, 11, 11]           --
# ├─ConvTranspose2d: 1-5                   [8, 32, 22, 22]           18,464
# ├─Sequential: 1-6                        [8, 32, 22, 22]           --
# │    └─Conv2d: 2-16                      [8, 32, 22, 22]           18,464
# │    └─BatchNorm2d: 2-17                 [8, 32, 22, 22]           64
# │    └─ReLU: 2-18                        [8, 32, 22, 22]           --
# ├─ConvTranspose2d: 1-7                   [8, 8, 44, 44]            2,312
# ├─Sequential: 1-8                        [8, 8, 44, 44]            --
# │    └─Conv2d: 2-19                      [8, 8, 44, 44]            1,160
# │    └─BatchNorm2d: 2-20                 [8, 8, 44, 44]            16
# │    └─ReLU: 2-21                        [8, 8, 44, 44]            --
# ├─ConvTranspose2d: 1-9                   [8, 4, 88, 88]            292
# ├─Sequential: 1-10                       [8, 16, 88, 88]           --
# │    └─Conv2d: 2-22                      [8, 16, 88, 88]           1,168
# │    └─BatchNorm2d: 2-23                 [8, 16, 88, 88]           32
# │    └─ReLU: 2-24                        [8, 16, 88, 88]           --
# ├─Conv2d: 1-11                           [8, 4, 88, 88]            68
# ==========================================================================================
# Total params: 63,496
# Trainable params: 63,496
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 329.90
# ==========================================================================================
# Input size (MB): 0.74
# Forward/backward pass size (MB): 34.69
# Params size (MB): 0.25
# Estimated Total Size (MB): 35.69
# ==========================================================================================
# =======================  verify   =========================================================
# ERROR: last layer size [8, 4, 88, 88] != vY shape [8, 88, 88] ; FAIL
# ==========================================================================================

# %% [markdown]
# # train

# %%
## train or load:
if REDO == True:
    trained = myTrain.TrainModel(dlTrain, dlVal, oOpt, EPOCHS_TO_RUN, hL, hS, oSch = oSch)
else:
    trained = myTrain.loadModel(MODEL_PATH)
# Out:
# Epoch    1 / 50 | Train Loss:  1.446 | Val Loss:  1.462 | Train Score:  0.217 | Val Score:  0.186 | Epoch Time: 28.04 | <-- Checkpoint Saved! |
# Epoch    2 / 50 | Train Loss:  1.409 | Val Loss:  1.384 | Train Score:  0.258 | Val Score:  0.310 | Epoch Time: 23.96 | <-- Checkpoint Saved! |
# Epoch    3 / 50 | Train Loss:  1.359 | Val Loss:  1.311 | Train Score:  0.318 | Val Score:  0.386 | Epoch Time: 24.01 | <-- Checkpoint Saved! |
# Epoch    4 / 50 | Train Loss:  1.280 | Val Loss:  1.243 | Train Score:  0.385 | Val Score:  0.428 | Epoch Time: 24.87 | <-- Checkpoint Saved! |
# Epoch    5 / 50 | Train Loss:  1.162 | Val Loss:  1.145 | Train Score:  0.487 | Val Score:  0.508 | Epoch Time: 24.02 | <-- Checkpoint Saved! |
# Epoch    6 / 50 | Train Loss:  1.031 | Val Loss:  1.037 | Train Score:  0.619 | Val Score:  0.647 | Epoch Time: 24.62 | <-- Checkpoint Saved! |
# Epoch    7 / 50 | Train Loss:  0.909 | Val Loss:  0.953 | Train Score:  0.791 | Val Score:  0.751 | Epoch Time: 24.20 | <-- Checkpoint Saved! |
# Epoch    8 / 50 | Train Loss:  0.806 | Val Loss:  0.821 | Train Score:  0.841 | Val Score:  0.814 | Epoch Time: 24.00 | <-- Checkpoint Saved! |
# Epoch    9 / 50 | Train Loss:  0.705 | Val Loss:  0.727 | Train Score:  0.861 | Val Score:  0.830 | Epoch Time: 24.57 | <-- Checkpoint Saved! |
# Epoch   10 / 50 | Train Loss:  0.613 | Val Loss:  0.642 | Train Score:  0.871 | Val Score:  0.835 | Epoch Time: 24.02 | <-- Checkpoint Saved! |
# Epoch   11 / 50 | Train Loss:  0.530 | Val Loss:  0.588 | Train Score:  0.879 | Val Score:  0.858 | Epoch Time: 24.12 | <-- Checkpoint Saved! |
# Epoch   12 / 50 | Train Loss:  0.458 | Val Loss:  0.472 | Train Score:  0.888 | Val Score:  0.875 | Epoch Time: 24.77 | <-- Checkpoint Saved! |
# Epoch   13 / 50 | Train Loss:  0.399 | Val Loss:  0.416 | Train Score:  0.896 | Val Score:  0.880 | Epoch Time: 23.97 | <-- Checkpoint Saved! |
# Epoch   14 / 50 | Train Loss:  0.353 | Val Loss:  0.383 | Train Score:  0.901 | Val Score:  0.886 | Epoch Time: 24.25 | <-- Checkpoint Saved! |
# Epoch   15 / 50 | Train Loss:  0.324 | Val Loss:  0.361 | Train Score:  0.902 | Val Score:  0.892 | Epoch Time: 24.78 | <-- Checkpoint Saved! |
# Epoch   16 / 50 | Train Loss:  0.291 | Val Loss:  0.328 | Train Score:  0.909 | Val Score:  0.895 | Epoch Time: 24.02 | <-- Checkpoint Saved! |
# Epoch   17 / 50 | Train Loss:  0.270 | Val Loss:  0.314 | Train Score:  0.912 | Val Score:  0.898 | Epoch Time: 24.76 | <-- Checkpoint Saved! |
# Epoch   18 / 50 | Train Loss:  0.252 | Val Loss:  0.296 | Train Score:  0.915 | Val Score:  0.900 | Epoch Time: 24.11 | <-- Checkpoint Saved! |
# Epoch   19 / 50 | Train Loss:  0.236 | Val Loss:  0.283 | Train Score:  0.918 | Val Score:  0.903 | Epoch Time: 23.95 | <-- Checkpoint Saved! |
# Epoch   20 / 50 | Train Loss:  0.227 | Val Loss:  0.306 | Train Score:  0.920 | Val Score:  0.890 | Epoch Time: 24.95 |
# Epoch   21 / 50 | Train Loss:  0.217 | Val Loss:  0.359 | Train Score:  0.921 | Val Score:  0.858 | Epoch Time: 24.53 |
# Epoch   22 / 50 | Train Loss:  0.207 | Val Loss:  0.261 | Train Score:  0.925 | Val Score:  0.905 | Epoch Time: 23.96 | <-- Checkpoint Saved! |
# Epoch   23 / 50 | Train Loss:  0.196 | Val Loss:  0.280 | Train Score:  0.928 | Val Score:  0.898 | Epoch Time: 24.80 |
# Epoch   24 / 50 | Train Loss:  0.195 | Val Loss:  0.258 | Train Score:  0.927 | Val Score:  0.903 | Epoch Time: 23.91 |
# Epoch   25 / 50 | Train Loss:  0.182 | Val Loss:  0.246 | Train Score:  0.931 | Val Score:  0.904 | Epoch Time: 24.72 |
# Epoch   26 / 50 | Train Loss:  0.180 | Val Loss:  0.241 | Train Score:  0.932 | Val Score:  0.910 | Epoch Time: 24.08 | <-- Checkpoint Saved! |
# Epoch   27 / 50 | Train Loss:  0.174 | Val Loss:  0.237 | Train Score:  0.934 | Val Score:  0.906 | Epoch Time: 24.07 |
# Epoch   28 / 50 | Train Loss:  0.175 | Val Loss:  0.230 | Train Score:  0.933 | Val Score:  0.911 | Epoch Time: 24.68 | <-- Checkpoint Saved! |
# Epoch   29 / 50 | Train Loss:  0.168 | Val Loss:  0.228 | Train Score:  0.936 | Val Score:  0.912 | Epoch Time: 23.98 | <-- Checkpoint Saved! |
# Epoch   30 / 50 | Train Loss:  0.164 | Val Loss:  0.219 | Train Score:  0.937 | Val Score:  0.913 | Epoch Time: 24.05 | <-- Checkpoint Saved! |
# Epoch   31 / 50 | Train Loss:  0.158 | Val Loss:  0.240 | Train Score:  0.939 | Val Score:  0.906 | Epoch Time: 25.59 |
# Epoch   32 / 50 | Train Loss:  0.160 | Val Loss:  0.219 | Train Score:  0.938 | Val Score:  0.916 | Epoch Time: 23.98 | <-- Checkpoint Saved! |
# Epoch   33 / 50 | Train Loss:  0.153 | Val Loss:  0.222 | Train Score:  0.941 | Val Score:  0.916 | Epoch Time: 24.40 |
# Epoch   34 / 50 | Train Loss:  0.152 | Val Loss:  0.234 | Train Score:  0.942 | Val Score:  0.906 | Epoch Time: 24.35 |
# Epoch   35 / 50 | Train Loss:  0.151 | Val Loss:  0.230 | Train Score:  0.942 | Val Score:  0.913 | Epoch Time: 24.10 |
# Epoch   36 / 50 | Train Loss:  0.149 | Val Loss:  0.229 | Train Score:  0.942 | Val Score:  0.911 | Epoch Time: 24.59 |
# Epoch   37 / 50 | Train Loss:  0.146 | Val Loss:  0.210 | Train Score:  0.944 | Val Score:  0.919 | Epoch Time: 23.97 | <-- Checkpoint Saved! |
# Epoch   38 / 50 | Train Loss:  0.142 | Val Loss:  0.216 | Train Score:  0.945 | Val Score:  0.916 | Epoch Time: 24.05 |
# Epoch   39 / 50 | Train Loss:  0.142 | Val Loss:  0.212 | Train Score:  0.945 | Val Score:  0.918 | Epoch Time: 25.00 |
# Epoch   40 / 50 | Train Loss:  0.140 | Val Loss:  0.212 | Train Score:  0.946 | Val Score:  0.918 | Epoch Time: 24.02 |
# Epoch   41 / 50 | Train Loss:  0.137 | Val Loss:  0.216 | Train Score:  0.947 | Val Score:  0.917 | Epoch Time: 24.00 |
# Epoch   42 / 50 | Train Loss:  0.137 | Val Loss:  0.220 | Train Score:  0.947 | Val Score:  0.916 | Epoch Time: 25.07 |
# Epoch   43 / 50 | Train Loss:  0.138 | Val Loss:  0.216 | Train Score:  0.946 | Val Score:  0.915 | Epoch Time: 24.11 |
# Epoch   44 / 50 | Train Loss:  0.136 | Val Loss:  0.216 | Train Score:  0.947 | Val Score:  0.917 | Epoch Time: 24.63 |
# Epoch   45 / 50 | Train Loss:  0.136 | Val Loss:  0.211 | Train Score:  0.947 | Val Score:  0.918 | Epoch Time: 24.02 |
# Epoch   46 / 50 | Train Loss:  0.136 | Val Loss:  0.211 | Train Score:  0.948 | Val Score:  0.918 | Epoch Time: 23.97 |
# Epoch   47 / 50 | Train Loss:  0.135 | Val Loss:  0.212 | Train Score:  0.948 | Val Score:  0.918 | Epoch Time: 24.62 |
# Epoch   48 / 50 | Train Loss:  0.134 | Val Loss:  0.211 | Train Score:  0.948 | Val Score:  0.918 | Epoch Time: 23.96 |
# Epoch   49 / 50 | Train Loss:  0.133 | Val Loss:  0.213 | Train Score:  0.948 | Val Score:  0.917 | Epoch Time: 23.91 |
# Epoch   50 / 50 | Train Loss:  0.134 | Val Loss:  0.211 | Train Score:  0.948 | Val Score:  0.917 | Epoch Time: 24.58 |

# %% [markdown]
# ## results

# %%
myTrain.plotTrainResults()

# %% [markdown]
# ## loss on test

# %%
test_score = myTrain.evaluate_test_data(testData = dlTest ,score_fn=hS)
# Out:
# Test Score: 0.9269707565162112

# %% [markdown]
# ## test case examine

# %%
def visualize_prediction(model, dataset, index):
    model.eval()
    image, label = dataset[index]
    image = image.unsqueeze(0)  

    with torch.no_grad():
        output = model(image)
        pred = torch.argmax(output, dim=1).cpu().squeeze(0)  # Remove batch dimension and move to CPU

    # Debugging: Check unique values in the output and prediction
    print("Unique values in the raw output:", np.unique(output.cpu().numpy()))
    print("Unique values in the predicted segmentation:", np.unique(pred.numpy()))

    # Convert the tensors to images for visualization
    image = image.cpu().squeeze(0).permute(1, 2, 0)  # Convert from (C, H, W) to (H, W, C)
    label = label.cpu()
    pred = pred.cpu()

    # Plot the images
    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    ax[0].imshow(image)
    ax[0].set_title('Input Image')
    ax[0].axis('off')

    ax[1].imshow(label)
    ax[1].set_title('Ground Truth')
    ax[1].axis('off')

    ax[2].imshow(pred)
    ax[2].set_title('Predicted Segmentation')
    ax[2].axis('off')

    plt.show()

# Visualize prediction on a sample image from the validation set
visualize_prediction(myTrain.model, val_dataset, index=1)
# Out:
# Unique values in the raw output: [-8.02511   -7.8556566 -7.681475  ...  5.3811636  5.440337   5.4773045]
# Unique values in the predicted segmentation: [0 1 2 3]

# %% [markdown]
# ## new test

# %%
from PIL import Image, ImageOps

def visualize_new_prediction(model,new_image_path):
    if not os.path.exists(new_image_path):
        return None
    model.eval()
    image = Image.open(new_image_path).convert('RGB')
    
    ## make the same size as the training image
    print(f"orig image.size = {image.size}")
    test_size = (960, 720)
    image = ImageOps.fit(image, test_size, method=Image.LANCZOS)
    print(f"image.size = {image.size}")
    


    
    image_tensor = image_transform(image).unsqueeze(0)

    with torch.no_grad():
        output = model(image_tensor)
        pred = torch.argmax(output, dim=1).cpu().squeeze(0)  # Remove batch dimension and move to CPU
    
    # Convert the tensor image to numpy for visualization
    image_model = image_tensor.cpu().squeeze(0).permute(1, 2, 0).numpy()  # Convert from (C, H, W) to (H, W, C)

    # Plot the images
    fig, ax = plt.subplots(1, 3, figsize=(15, 5))
    ax[0].imshow(image)
    ax[0].set_title('Input Image')
    ax[0].axis('off')
    
    ax[1].imshow(image_model)
    ax[1].set_title('Model Image')
    ax[1].axis('off')

    ax[2].imshow(pred)
    ax[2].set_title('Predicted Segmentation')
    ax[2].axis('off')

    plt.show()

visualize_new_prediction(myTrain.model,'/home/vlad/Data/myTestImg/carPark1.jpeg')    
visualize_new_prediction(myTrain.model,'/data/tinyai/maxCNN/ai8x-training/data/CamVid/test/0016E5_08025.png')    
visualize_new_prediction(myTrain.model,'/data/solai/projB/1_unteSmall/results/carPark1.jpeg')    
visualize_new_prediction(myTrain.model,'/data/solai/projB/1_unteSmall/results/newTest1.jpg')
# Out:
# orig image.size = (721, 1600)
# image.size = (960, 720)

# %% [markdown]
# # report

# %%
print(f"trainning   : EPOCHS_TO_RUN={EPOCHS_TO_RUN} ; batch={BATCH_SIZE}")
print(f"model       : file={MODEL_PATH}")
print(f"input data  : train_len =  {len(dlTrain.dataset)} ; test_len={len(dlVal.dataset)} ; val_len={len(dlTest.dataset)} ")
print(f"img data    : IMAGE_SIZE={IMAGE_SIZE}")
print(f"model       : NUM_CLASS={NUM_CLASS} ; NUM_CHANN={NUM_CHANN} ; FOLD_RATIO={FOLD_RATIO}")
print(f"score       : val_score={myTrain.lValScore[-1]} ; val_loss {myTrain.lValLoss[-1]}")
print(f"            : test_score={test_score}")
print(f"Trainable parameters: {myTrain.parma_stat()['trainable_params']}")
print(f"parameters_size_in_megabytes : {myTrain.parma_stat()['total_size_in_megabytes']}")
# Out:
# trainning   : EPOCHS_TO_RUN=50 ; batch=8
# model       : file=/tmp/unet_model_small_x88_c3_e50_F1.pt
# input data  : train_len =  369 ; test_len=232 ; val_len=100
# img data    : IMAGE_SIZE=(88, 88)
# model       : NUM_CLASS=4 ; NUM_CHANN=3 ; FOLD_RATIO=1
# score       : val_score=0.9170481262467941 ; val_loss 0.2111915853516809
#             : test_score=0.9269707565162112
# Trainable parameters: 63496
# parameters_size_in_megabytes : 0.242218017578125
